# %% [markdown]
# # Working With Data – Tasks and Quiz Questions

# %% [markdown]
# ## Setup
# Import the required packages.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load the Data
# Import the dataset from GitHub and assign it to df.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/juanklopper/TutorialData/main/PUBH1142Chap0801.csv')

# %% [markdown]
# ## Task 1
# Read about methods and attributes of a pandas dataframe object.

# %%
dir(df)[:20]
# Out:
# ['Age',
#  'CholesterolAfter',
#  'CholesterolBefore',
#  'DOB',
#  'Delta',
#  'Group',
#  'HR',
#  'Name',
#  'Smoke',
#  'Survey',
#  'T',
#  'TAG',
#  'Vocation',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__']

# %% [markdown]
# ## Task 2
# Select the Vocation column and assign it to the variable vocation. Confirm that the object assigned to vocation is a pandas Series object. Then print the last five observations.

# %%
vocation = df.Vocation
type(vocation)
# Out:
# pandas.Series

# %%
vocation.tail()
# Out:
# 195            Sales professional, IT
# 196                         Paramedic
# 197    Chartered certified accountant
# 198                            Dancer
# 199                Theme park manager
# Name: Vocation, dtype: str

# %% [markdown]
# ## Task 3
# Print the TAG and Smoke variables for observations 10 through 15.

# %%
df.loc[10:15, ['TAG', 'Smoke']]
# Out:
#     TAG  Smoke
# 10  1.7      0
# 11  2.0      0
# 12  2.3      0
# 13  2.1      0
# 14  2.4      0
# 15  2.6      2

# %% [markdown]
# ## Task 4
# Use the to_list method to create a Python list object of the Age values for those with HR greater than 72. Print only the first 10 values.

# %%
df.loc[df.HR > 72, 'Age'].to_list()[:10]
# Out:
# [57, 52, 49, 70, 45, 53, 50, 33, 30, 44]

# %% [markdown]
# ## Task 5
# Create a variable named selection that selects observations who never smoked, have HR less than 80, and sBP less than 120. Use this selection to create a numpy array of Age and TAG values.

# %%
selection = (df.Smoke == 0) & (df.HR < 80) & (df.sBP < 120)
df.loc[selection, ['Age', 'TAG']].to_numpy()
# Out:
# array([[53. ,  0.6],
#        [43. ,  1.6],
#        [44. ,  2.4],
#        [35. ,  2. ],
#        [45. ,  2.1],
#        [55. ,  3.1]])

# %% [markdown]
# ## Task 6
# Create a new variable named AgeHR that is the product of Age and HR.

# %%
df['AgeHR'] = df.Age * df.HR
df[['Age', 'HR', 'AgeHR']].head()
# Out:
#    Age  HR  AgeHR
# 0   43  47   2021
# 1   53  51   2703
# 2   33  54   1782
# 3   43  54   2322
# 4   46  61   2806

# %% [markdown]
# # Quiz Questions

# %% [markdown]
# ## Question 1
# How do you import the pandas package in Python?

# %%
import pandas as pd

# %% [markdown]
# ## Question 2
# What function do you use to read a CSV file in pandas?

# %%
df = pd.read_csv('https://raw.githubusercontent.com/juanklopper/TutorialData/main/PUBH1142Chap0801.csv')

# %% [markdown]
# ## Question 3
# How do you display the first 5 rows of a DataFrame in pandas?

# %%
df.head()
# Out:
#                 Name         DOB  Age               Vocation  Smoke  HR  sBP  \
# 0       Dylan Patton  1981-10-07   43         Energy manager      0  47  145
# 1      Sandra Howard  1993-01-27   53            Tax adviser      0  51  115
# 2  Samantha Williams  1973-12-21   33          IT consultant      0  54  120
# 3     Ashley Hensley  1981-12-01   43      Nurse, children's      0  54  103
# 4      Robert Wilson  1964-06-23   46  Clinical embryologist      0  61  138
#
#    CholesterolBefore  TAG  Survey  CholesterolAfter  Delta   Group
# 0                1.2  1.2       1               0.7    0.5  Active
# 1                1.2  0.6       3               1.0    0.2  Active
# 2                2.0  1.3       3               1.7    0.3  Active
# 3                2.1  1.6       4               2.1    0.0  Active
# 4                2.8  2.1       5               2.8    0.0  Active

# %% [markdown]
# ## Question 4
# How do you calculate the mean of a column named Age in a DataFrame named df?

# %%
df['Age'].mean()
# Out:
# np.float64(53.07)

# %% [markdown]
# ## Question 5
# How do you calculate the median of the HR column in df?

# %%
df['HR'].median()
# Out:
# np.float64(73.0)

# %% [markdown]
# ## Question 6
# How do you calculate the standard deviation of the TAG column in a DataFrame named df?

# %%
df['TAG'].std()
# Out:
# np.float64(1.0397255146088524)

# %% [markdown]
# ## Question 7
# How do you find the number of missing values in each column of a DataFrame named df?

# %%
df.isnull().sum()
# Out:
# Name                 0
# DOB                  0
# Age                  0
# Vocation             0
# Smoke                0
# HR                   0
# sBP                  0
# CholesterolBefore    0
# TAG                  0
# Survey               0
# CholesterolAfter     0
# Delta                0
# Group                0
# dtype: int64

# %% [markdown]
# ## Question 8
# How do you calculate the correlation between Age and HR in a DataFrame named df?

# %%
df['Age'].corr(df['HR'])
# Out:
# np.float64(0.33598629194043)

# %% [markdown]
# ## Question 9
# How do you select a subset of a DataFrame df where Age is greater than 30?

# %%
df[df['Age'] > 30]
# Out:
#                   Name         DOB  Age                        Vocation  \
# 0         Dylan Patton  1981-10-07   43                  Energy manager
# 1        Sandra Howard  1993-01-27   53                     Tax adviser
# 2    Samantha Williams  1973-12-21   33                   IT consultant
# 3       Ashley Hensley  1981-12-01   43               Nurse, children's
# 4        Robert Wilson  1964-06-23   46           Clinical embryologist
# ..                 ...         ...  ...                             ...
# 195        John Curtis  1936-11-25   66          Sales professional, IT
# 196     Jessica Tanner  1986-07-01   54                       Paramedic
# 197      Charles Smith  1959-01-30   61  Chartered certified accountant
# 198       Barry Porter  1979-05-30   65                          Dancer
# 199      Julie Barrett  1972-07-27   66              Theme park manager
#
#      Smoke   HR  sBP  CholesterolBefore  TAG  Survey  CholesterolAfter  Delta  \
# ...

# %% [markdown]
# ## Question 10
# How do you calculate the range (maximum - minimum) of the TAG column in a DataFrame named df?

# %%
df['TAG'].max() - df['TAG'].min()
# Out:
# np.float64(5.1000000000000005)

# %% [markdown]
# ## Question 11
# How do you group a DataFrame df by Group and calculate the mean of Age within each group?

# %%
df.groupby('Group')['Age'].mean()
# Out:
# Group
# Active     53.61
# Control    52.53
# Name: Age, dtype: float64

# %% [markdown]
# ## Question 12
# How do you group a DataFrame df by Group and Vocation and count the number of rows within each group?

# %%
df.groupby(['Group', 'Vocation']).size()
# Out:
# Group    Vocation
# Active   Accommodation manager                 1
#          Accountant, chartered certified       1
#          Administrator, sports                 1
#          Adult guidance worker                 1
#          Animal technologist                   1
#                                               ..
# Control  Therapeutic radiographer              1
#          Therapist, horticultural              1
#          Tourist information centre manager    1
#          Trading standards officer             1
#          Waste management officer              2
# Length: 181, dtype: int64

# %% [markdown]
# ## Question 13
# How do you use the groupby method to find the maximum Age in each Group in a DataFrame df?

# %%
df.groupby('Group')['Age'].max()
# Out:
# Group
# Active     75
# Control    74
# Name: Age, dtype: int64

# %% [markdown]
# ## Question 14
# How do you create a cross-tabulation table that shows the frequency count of Group (rows) and Smoke (columns) in a DataFrame df?

# %%
pd.crosstab(df['Group'], df['Smoke'])
# Out:
# Smoke     0   1   2
# Group
# Active   41  45  14
# Control  47  40  13

# %% [markdown]
# ## Question 15
# How do you create a cross-tabulation table that shows the mean HR for each combination of Group (rows) and Smoke (columns) in a DataFrame df?

# %%
pd.crosstab(df['Group'], df['Smoke'], values=df['HR'], aggfunc='mean')
# Out:
# Smoke            0          1          2
# Group
# Active   70.487805  82.622222  77.142857
# Control  69.787234  76.150000  70.538462

# %% [markdown]
# ## Optional
# Display the column names in the dataset.

# %%
df.columns
# Out:
# Index(['Name', 'DOB', 'Age', 'Vocation', 'Smoke', 'HR', 'sBP',
#        'CholesterolBefore', 'TAG', 'Survey', 'CholesterolAfter', 'Delta',
#        'Group'],
#       dtype='str')
